# %%
import pandas as pd

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %%
df
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# 1                Living Environment  2015            16       77.9
# ...

# %%
df.describe()
# using the df.describe function to get a breakdown of the dataset
# Out:
#                 Year   Total Tested
# count  212331.000000  212331.000000
# mean     2015.956069      49.364200
# std         0.799726      93.023576
# min      2015.000000       1.000000
# 25%      2015.000000       5.000000
# 50%      2016.000000      20.000000
# 75%      2017.000000      57.000000
# max      2017.000000    1729.000000

# %%
df. groupby(['Year'])['Mean Score'].count().sort_values
# Out:
# <bound method Series.sort_values of Year
# 2015    47931
# 2016    47064
# 2017    42114
# Name: Mean Score, dtype: int64>

# %%
sns.boxplot(x="Year", y="Mean Score", data=df2).set(title='Mean Score')
# Out:
# [Text(0.5, 1.0, 'Mean Score')]

# %%
df2 = df[['Year', 'Mean Score']]
# selecting multiple columns from our dataframe to create a subset

# %%
df2
# Out:
#         Year  Mean Score
# 0       2017         NaN
# 1       2015        77.9
# 2       2016        74.0
# 3       2016         NaN
# 4       2017         NaN
# ...      ...         ...
# 212326  2016         NaN
# 212327  2016         NaN
# 212328  2017         NaN
# 212329  2017         NaN
# 212330  2015         NaN
#
# [212331 rows x 2 columns]

# %%
# All columns
df.columns
# Out:
# Index(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
#        'Total Tested', 'Mean Score', 'Number Scoring Below 65',
#        'Percent Scoring Below 65', 'Number Scoring 65 or Above',
#        'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
#        'Percent Scoring 80 or Above', 'Number Scoring CR',
#        'Percent Scoring CR'],
#       dtype='object')

# %%
# Desided to drop the CR (Credit) columns because they are not relevant for the purpose of my investigation
drop_cols = ['Number Scoring CR', 'Percent Scoring CR']
df.drop(drop_cols, axis=1, inplace=True)

# %%
df
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# 1                Living Environment  2015            16       77.9
# ...

# %%
# Changing missing values to NaN
missing_values = ["n/a", "na", "s", "--"]

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv',na_values = missing_values)

# %%
df.head(20)
# Out:
#    School DBN                     School Name School Level  \
# 0      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3      01M140          P.S. 140 Nathan Straus          K-8
# 4      01M140          P.S. 140 Nathan Straus          K-8
# 5      01M140          P.S. 140 Nathan Straus          K-8
# 6      01M140          P.S. 140 Nathan Straus          K-8
# 7      01M140          P.S. 140 Nathan Straus          K-8
# 8      01M184            P.S. 184m Shuang Wen          K-8
# 9      01M184            P.S. 184m Shuang Wen          K-8
# 10     01M184            P.S. 184m Shuang Wen          K-8
# 11     01M184            P.S. 184m Shuang Wen          K-8
# 12     01M188      P.S. 188 The Island School          K-8
# 13     01M188      P.S. 188 The Island School          K-8
# 14     01M188      P.S. 188 The Island School          K-8
# ...

# %%
df.iloc[2]
# using the iloc function to isolate a row
# Out:
# School DBN                                             01M034
# School Name                    P.S. 034 Franklin D. Roosevelt
# School Level                                              K-8
# Regents Exam                               Living Environment
# Year                                                     2016
# Total Tested                                                9
# Mean Score                                               74.0
# Number Scoring Below 65                                   1.0
# Percent Scoring Below 65                                 11.1
# Number Scoring 65 or Above                                8.0
# Percent Scoring 65 or Above                              88.9
# Number Scoring 80 or Above                                2.0
# Percent Scoring 80 or Above                              22.2
# Number Scoring CR                                         NaN
# Percent Scoring CR                                        NaN
# Name: 2, dtype: object

# %%
df.plot(kind='scatter', x='Year', y= 'Mean Score')

# %% [markdown]
# Notes: The comparision portion of the assignment is missing since I got stuck and couldn't figure it out. I have been reviewing notes and the class recording so hopefully following assignments would be complete :)
